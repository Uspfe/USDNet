# %% [markdown]
# Run motion inference. Results are moved to `results/inference_mov_articulation` (`/mov_test`)

# %%
# !pixi run bash ./scripts/infer_mov.sh
# Out:
# ⠁ activating environment                                                                 /home/benni/repos/USDNet/.pixi/envs/default/lib/python3.12/site-packages/torchmetrics/__init__.py:31: UserWarning: A NumPy version >=1.26.4 and <2.7.0 is required for this version of SciPy (detected version 1.26.0)
#   import scipy.signal
# /home/benni/repos/USDNet/trainer/trainer.py:1865: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert (False, "class not known!")
# /home/benni/repos/USDNet/.pixi/envs/default/lib/python3.12/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'config_articulation_instance_segmentation.yaml': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Visualize groundtruth

# %%
# !pixi run bash ./scripts/infer_inter.sh
# Out:
# ./scripts/infer_inter.sh: line 9: cd: USDNet: No such file or directory
# /home/benni/repos/USDNet/.pixi/envs/default/lib/python3.12/site-packages/torchmetrics/__init__.py:31: UserWarning: A NumPy version >=1.26.4 and <2.7.0 is required for this version of SciPy (detected version 1.26.0)
#   import scipy.signal
# /home/benni/repos/USDNet/trainer/trainer.py:1865: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert (False, "class not known!")
# /home/benni/repos/USDNet/.pixi/envs/default/lib/python3.12/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'config_articulation_instance_segmentation.yaml': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# ...

# %%
# !pixi run python visualize_groundtruth.py --scene-id 30f4a2b44d
# Out:
# ⠁ activating environment                                                                 Using ScanNet directory: /home/benni/repos/ScanNet++/data
# Loading scene 30f4a2b44d
#   Parts: /home/benni/repos/USDNet/data/raw/articulate3d/30f4a2b44d_parts.json
#   Articulations: /home/benni/repos/USDNet/data/raw/articulate3d/30f4a2b44d_artic.json
#   Mesh: /home/benni/repos/ScanNet++/data/data/30f4a2b44d/scans/mesh_aligned_0.05.ply
# Loaded 38 parts and 18 articulations
# Inferred 25 connectivity edges from label hierarchy
# Rendered 18 articulation joints
#
# ...
# Scene: 30f4a2b44d
# Total vertices: 1304672
# Annotated parts: 38
# Objects: 38
# Articulations: 18
# Scene bounds: [0.01522982 0.04908429 0.04651188] to [4.87360907 3.74217772 3.38534474]
# ...
#
# Color legend:
#   - Each distinct color represents a different part
#   - Gray: unannotated vertices
#
# Articulation colors:
#   - Red: rotation joints
#   - Blue: translation joints
#   - Circular ring: indicates rotational motion

# %%
# !pixi run python visualize_results.py --split validation --scene 30f4a2b44d --draw-pred-masks
# Out:
# ⠁ activating environment                                                                 Loaded: /home/benni/repos/USDNet/data/processed/articulate3d_challenge_inter/validation/30f4a2b44d.npy
# Shape: (278336, 13), dtype: float32
# Loading predicted masks...
#   Loaded mask for obj 1: /home/benni/repos/USDNet/results/inference_inter_seg/inter_test/predicted_masks/30f4a2b44d_1.txt (shape=(278336,))
#   Loaded mask for obj 1: /home/benni/repos/USDNet/results/inference_inter_seg/inter_test/predicted_masks/30f4a2b44d_1.txt (shape=(278336,))
#   Loaded mask for obj 2: /home/benni/repos/USDNet/results/inference_inter_seg/inter_test/predicted_masks/30f4a2b44d_2.txt (shape=(278336,))
#   Loaded mask for obj 2: /home/benni/repos/USDNet/results/inference_inter_seg/inter_test/predicted_masks/30f4a2b44d_2.txt (shape=(278336,))
#   Loaded mask for obj 3: /home/benni/repos/USDNet/results/inference_inter_seg/inter_test/predicted_masks/30f4a2b44d_3.txt (shape=(278336,))
# ...

# %% [markdown]
# # Run inference on custom point cloud
